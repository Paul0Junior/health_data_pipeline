# %% [markdown]
# # Análise de API's (Open FDA)

# %% [markdown]
# ### Importando bibliotecas:

# %%
import pandas as pd
import duckdb
import httpx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 4
#       2 import duckdb
#       3 import httpx
# ----> 4 import pandera
#
# ModuleNotFoundError: No module named 'pandera'

# %% [markdown]
# ### Estruturando os dados:

# %%
# Buscando os dados
response = httpx.get('https://api.fda.gov/drug/event.json?search=serious:1&limit=10')
data = response.json()

# %%
# Estruturando os dados
df = pd.DataFrame(data['results'])
df.head()
# Out:
#   safetyreportid transmissiondateformat transmissiondate serious  \
# 0      5801206-7                    102         20090109       1
# 1       10003300                    102         20141002       1
# 2       10003301                    102         20141002       1
# 3       10003311                    102         20151125       1
# 4       10003312                    102         20141212       1
#
#   seriousnessdeath receivedateformat receivedate receiptdateformat  \
# 0                1               102    20080707               102
# 1              NaN               102    20140306               102
# 2              NaN               102    20140228               102
# 3              NaN               102    20140312               102
# 4              NaN               102    20140312               102
#
#   receiptdate fulfillexpeditecriteria  ... safetyreportversion  \
# 0    20080625                       1  ...                 NaN
# 1    20140306                       2  ...                   1
# 2    20140228                       2  ...                   1
# 3    20150812                       2  ...                   3
# 4    20140417                       1  ...                   2
#
#   primarysourcecountry reporttype seriousnessdisabling duplicate  \
# 0                  NaN        NaN                  NaN       NaN
# 1                   US          1                    1         1
# 2                   US          1                  NaN         1
# 3                   US          1                  NaN         1
# 4                   US          2                  NaN         1
#
#                                      reportduplicate seriousnessother  \
# 0                                                NaN              NaN
# 1  {'duplicatesource': 'GENENTECH', 'duplicatenum...              NaN
# 2  {'duplicatesource': 'JANSSEN', 'duplicatenumb'...                1
# 3  {'duplicatesource': 'GILEAD', 'duplicatenumb':...              NaN
# 4  {'duplicatesource': 'NOVARTIS', 'duplicatenumb...                1
#
#   occurcountry seriousnesshospitalization seriousnesslifethreatening
# 0          NaN                        NaN                        NaN
# 1          NaN                        NaN                        NaN
# 2          NaN                        NaN                        NaN
# 3           US                          1                        NaN
# 4           US                          1                          1
#
# [5 rows x 25 columns]

# %%
# Analisando os dados:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   safetyreportid              10 non-null     object
#  1   transmissiondateformat      10 non-null     object
#  2   transmissiondate            10 non-null     object
#  3   serious                     10 non-null     object
#  4   seriousnessdeath            3 non-null      object
#  5   receivedateformat           10 non-null     object
#  6   receivedate                 10 non-null     object
#  7   receiptdateformat           10 non-null     object
#  8   receiptdate                 10 non-null     object
#  9   fulfillexpeditecriteria     10 non-null     object
#  10  companynumb                 10 non-null     object
#  11  primarysource               10 non-null     object
#  12  sender                      10 non-null     object
#  13  receiver                    9 non-null      object
#  14  patient                     10 non-null     object
#  15  safetyreportversion         9 non-null      object
#  16  primarysourcecountry        9 non-null      object
#  17  reporttype                  9 non-null      object
#  18  seriousnessdisabling        1 non-null      object
#  19  duplicate                   9 non-null      object
#  20  reportduplicate             9 non-null      object
#  21  seriousnessother            5 non-null      object
#  22  occurcountry                7 non-null      object
#  23  seriousnesshospitalization  5 non-null      object
#  24  seriousnesslifethreatening  2 non-null      object
# dtypes: object(25)
# memory usage: 2.1+ KB
