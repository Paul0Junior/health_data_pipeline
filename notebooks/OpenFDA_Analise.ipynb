# %% [markdown]
# # Análise de API's (Open FDA)

# %% [markdown]
# ### Importando bibliotecas:

# %%
import pandas as pd
import duckdb
import httpx
import pandera.pandas as pa
from pandera.typing import Series
import pyarrow
import duckdb

# %% [markdown]
# ### Estruturando os dados:

# %%
# Buscando os dados
response = httpx.get('https://api.fda.gov/drug/event.json?search=serious:1&limit=10')
data = response.json()

# %%
# Estruturando os dados
df = pd.json_normalize(data['results'])
df.head()
# Out:
#   safetyreportid transmissiondateformat transmissiondate serious  \
# 0      5801206-7                    102         20090109       1
# 1       10003300                    102         20141002       1
# 2       10003301                    102         20141002       1
# 3       10003311                    102         20151125       1
# 4       10003312                    102         20141212       1
#
#   seriousnessdeath receivedateformat receivedate receiptdateformat  \
# 0                1               102    20080707               102
# 1              NaN               102    20140306               102
# 2              NaN               102    20140228               102
# 3              NaN               102    20140312               102
# 4              NaN               102    20140312               102
#
#   receiptdate fulfillexpeditecriteria  ... sender.sendertype  \
# 0    20080625                       1  ...               NaN
# 1    20140306                       2  ...                 2
# 2    20140228                       2  ...                 2
# 3    20150812                       2  ...                 2
# 4    20140417                       1  ...                 2
#
#    receiver.receivertype receiver.receiverorganization seriousnessother  \
# 0                    NaN                           NaN              NaN
# 1                      6                           FDA              NaN
# 2                      6                           FDA                1
# 3                      6                           FDA              NaN
# 4                      6                           FDA                1
#
#   occurcountry seriousnesshospitalization patient.patientagegroup  \
# 0          NaN                        NaN                     NaN
# 1          NaN                        NaN                     NaN
# 2          NaN                        NaN                     NaN
# 3           US                          1                       6
# 4           US                          1                     NaN
#
#   patient.summary.narrativeincludeclinical  seriousnesslifethreatening  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
# 3                CASE EVENT DATE: 20120601                         NaN
# 4                                      NaN                           1
#
#    patient.patientweight
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                   41.8
#
# [5 rows x 39 columns]

# %%
# Analisando os dados:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 39 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   safetyreportid                               10 non-null     object
#  1   transmissiondateformat                       10 non-null     object
#  2   transmissiondate                             10 non-null     object
#  3   serious                                      10 non-null     object
#  4   seriousnessdeath                             3 non-null      object
#  5   receivedateformat                            10 non-null     object
#  6   receivedate                                  10 non-null     object
#  7   receiptdateformat                            10 non-null     object
#  8   receiptdate                                  10 non-null     object
#  9   fulfillexpeditecriteria                      10 non-null     object
#  10  companynumb                                  10 non-null     object
#  11  receiver                                     0 non-null      float64
#  12  primarysource.reportercountry                10 non-null     object
#  13  primarysource.qualification                  10 non-null     object
#  14  sender.senderorganization                    10 non-null     object
#  15  patient.patientonsetage                      8 non-null      object
#  16  patient.patientonsetageunit                  8 non-null      object
#  17  patient.patientsex                           10 non-null     object
#  18  patient.patientdeath.patientdeathdateformat  0 non-null      float64
#  19  patient.patientdeath.patientdeathdate        0 non-null      float64
#  20  patient.reaction                             10 non-null     object
#  21  patient.drug                                 10 non-null     object
#  22  safetyreportversion                          9 non-null      object
#  23  primarysourcecountry                         9 non-null      object
#  24  reporttype                                   9 non-null      object
#  25  seriousnessdisabling                         1 non-null      object
#  26  duplicate                                    9 non-null      object
#  27  reportduplicate.duplicatesource              9 non-null      object
#  28  reportduplicate.duplicatenumb                9 non-null      object
#  29  sender.sendertype                            9 non-null      object
#  30  receiver.receivertype                        9 non-null      object
#  31  receiver.receiverorganization                9 non-null      object
#  32  seriousnessother                             5 non-null      object
#  33  occurcountry                                 7 non-null      object
#  34  seriousnesshospitalization                   5 non-null      object
#  35  patient.patientagegroup                      1 non-null      object
#  36  patient.summary.narrativeincludeclinical     2 non-null      object
#  37  seriousnesslifethreatening                   2 non-null      object
#  38  patient.patientweight                        3 non-null      object
# dtypes: float64(3), object(36)
# memory usage: 3.2+ KB

# %% [markdown]
# ### Criando contrato de dados (Pandera)

# %%
schema = pa.DataFrameSchema(
    columns={
        "serious": pa.Column(int, coerce=True),
        "receiver.receiverorganization": pa.Column(str, nullable=True),
        "patient.patientsex": pa.Column(int, nullable=True, coerce=True)
    },
    strict="filter" #Ignora colunas que não estão no schema
)

# %%
# Validando o dataframe:
validated_df = schema.validate(df)
print(validated_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   serious                        10 non-null     int64
#  1   patient.patientsex             10 non-null     int64
#  2   receiver.receiverorganization  9 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes
# None

# %% [markdown]
# ### Salvando os resultados em .parquet

# %%
folder = '/home/jovyan/work/Data/OpenFDA/'
validated_df.to_parquet(f"{folder}adverse_events.parquet", engine='pyarrow')
print('Arquivo .parquet Salvo')
# Out:
# Arquivo .parquet Salvo

# %% [markdown]
# ### Lendo os resultados com DuckDB

# %%
dados = '/home/jovyan/work/Data/OpenFDA/adverse_events.parquet'

duckdb.sql(f"""

Select * from read_parquet('{dados}')

""").df()
# Out:
#    serious patient.patientsex receiver.receiverorganization
# 0        1                  1                          None
# 1        1                  2                           FDA
# 2        1                  2                           FDA
# 3        1                  2                           FDA
# 4        1                  2                           FDA
# 5        1                  1                           FDA
# 6        1                  1                           FDA
# 7        1                  2                           FDA
# 8        1                  2                           FDA
# 9        1                  1                           FDA
